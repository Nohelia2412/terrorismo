# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Datos/globalterrorismo.xlsx')

df.sample(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 135473  201407230027   2014       7    23        NaN         0        NaT
# 32542   198710300010   1987      10    30        NaN         0        NaT
# 123473  201311150029   2013      11    15        NaN         0        NaT
# 176174  201705240037   2017       5    24        NaN         0        NaT
# 143970  201502030001   2015       2     3        NaN         0        NaT
# 207212  202009120028   2020       9    12        NaN         0        NaT
# 147936  201505060093   2015       5     6        NaN         0        NaT
# 203589  202004150016   2020       4    15        NaN         0        NaT
# 186677  201805170042   2018       5    17        NaN         0        NaT
# 17429   198211120005   1982      11    12        NaN         0        NaT
#
#         country     country_txt  region  ...  \
# 135473       60           Egypt      10  ...
# 32542        45        Colombia       3  ...
# ...

# %%
df.shape
# Out:
# (209706, 135)

# %%
df.columns    #Visualizamos el nombre las columnas para seleccionar 6
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
selected_columns = df[['country_txt','region','targtype1','weaptype1','country','imonth','iday']]

selected_columns.head(10)
# Out:
#           country_txt  region  targtype1  weaptype1  country  imonth  iday
# 0  Dominican Republic       2         14         13       58       7     2
# 1              Mexico       1          7         13      130       0     0
# 2         Philippines       5         10         13      160       1     0
# 3              Greece       8          7          6       78       1     0
# 4               Japan       4          7          8      101       1     0
# 5       United States       1          3          5      217       1     1
# 6             Uruguay       3          3          5      218       1     2
# 7       United States       1         21          6      217       1     2
# 8       United States       1          4          8      217       1     2
# 9       United States       1          2          8      217       1     3

# %%
selected_columns.to_csv("Datos/globalterrorismo_nuevo.csv", index=False)
